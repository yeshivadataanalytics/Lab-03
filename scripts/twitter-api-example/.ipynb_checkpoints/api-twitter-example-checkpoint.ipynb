# %%
####################
#Author: brandon chiazza
#version: 1.0
#purpose: to call a twitter api and return results
#documentation: https://developer.twitter.com/en/docs
#####################

import pandas as pd
import requests
import json
import base64
import s3fs # documentation: https://s3fs.readthedocs.io/en/latest/
import time
import twitter_keys #this is a custom reference module to a package containing twitter keys

# %config IPCompleter.greedy=True


key_secret = '{}:{}'.format(twitter_keys.client_key, twitter_keys.client_secret).encode('ascii')
b64_encoded_key = base64.b64encode(key_secret)
b64_encoded_key = b64_encoded_key.decode('ascii')

#identify base url and oauth token path
base_url = 'https://api.twitter.com/' #base url for authentication
auth_url = '{}oauth2/token'.format(base_url)

#share header information -- encoding is ascii
auth_headers = {
    'Authorization': 'Basic {}'.format(b64_encoded_key),
    'Content-Type': 'application/x-www-form-urlencoded;charset=UTF-8'
}

#pass clientcredentials
auth_data = {
    'grant_type': 'client_credentials'
}

#send authentication using requests - POST request
auth_resp = requests.post(auth_url, headers=auth_headers, data=auth_data)

#check response status. 200 = OK
auth_resp.status_code
# Out:
# 200

# %%
#Keys in data response are token_type (bearer) and access_token (your access token)
print(auth_resp.json().keys())

access_token = auth_resp.json()['access_token']


search_headers = {
    'Authorization': 'Bearer {}'.format(access_token)    
}

#enter search parameters for coronavirus example. This looks for "covid-19" in the 1000 most recent tweets
query_params = {
    'q': 'covid-19',
    'result_type': 'recent',
    'count': 100, #update here to get more/less than 1000 returns
    'lang': 'en' #filters by english language only
}


#identify search url path and save 
search_url = '{}1.1/search/tweets.json'.format(base_url)


#run search using get request
search_resp = requests.get(search_url, headers=search_headers, params=query_params)

#check status code of GET request
search_resp.status_code
# Out:
# dict_keys(['token_type', 'access_token'])
# 200

# %%
#print text from result to verify  
twitter_data = search_resp.json()

for x in twitter_data['statuses']:
    print(x['text'] + '\n')
    break #prints after one iteration and stops, remove break to see all 1000
# Out:
# RT @doolsetbangtan: BGM: @BTS_twt -  With Seoul
#
# Yesterday, Korea reported zero new local COVID-19 cases for the first time in months. The…

# %%
# move data into data frame 
df = pd.DataFrame(twitter_data['statuses'])

# show one record to verify import 
df.head(1)
# Out:
#   contributors coordinates                      created_at  \
# 0         None        None  Fri May 01 00:59:54 +0000 2020
#
#                                             entities extended_entities  \
# 0  {'hashtags': [], 'symbols': [], 'user_mentions...               NaN
#
#    favorite_count  favorited   geo                   id               id_str  \
# 0               0      False  None  1256025519965057024  1256025519965057024
#
#    ... possibly_sensitive  quoted_status_id quoted_status_id_str  \
# 0  ...                NaN      1.255852e+18  1255852107673907202
#
#    retweet_count retweeted                                   retweeted_status  \
# 0           3834     False  {'created_at': 'Thu Apr 30 18:48:41 +0000 2020...
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text truncated  \
# 0  RT @doolsetbangtan: BGM: @BTS_twt -  With Seou...     False
#
#                                                 user
# 0  {'id': 975152528986918912, 'id_str': '97515252...
#
# [1 rows x 29 columns]

# %%
# we can use pandas to put data directly into an s3 bucket
#prepare csv file name   
filename = 'C:/Users/julir/source/repos/Lab3/scripts/'#specify location of s3:/{my-bucket}/
groupname= 'Group_4_' #name of your group
datetime = time.strftime("%Y%m%d%H%M%S") #timestamp
filenames3 = "%s%s%s.csv"%(filename,groupname,datetime) #name of the filepath and csv file

print(filenames3)
df.to_csv(filenames3, header = True)
# Out:
# C:/Users/julir/source/repos/Lab3/scripts/Group_4_20200430200004.csv

# %%
# we can use pandas to put data directly into an s3 bucket
#prepare csv file name   
#filename = 's3:/lab-03/'#specify location of s3:/{my-bucket}/
#groupname= 'Group_1_' #name of your group
#datetime = time.strftime("%Y%m%d%H%M%S") #timestamp
#filenames3 = "%s%s%s.csv"%(filename,groupname,datetime) #name of the filepath and csv file



#encoding must be adjusted to accommodate abnormal characters. Use s3fs to write to S3 bucket
byte_encoded_df = df.to_csv(None).encode() #encodes file as binary
s3 = s3fs.S3FileSystem(anon=False)
with s3.open(filenames3, 'wb') as file:
    file.write(byte_encoded_df) #writes byte-encoded file to s3 location

#print success message
print("Successfull uploaded file to location:"+str(filenames3))
# Out:
# ---------------------------------------------------------------------------
# ParamValidationError                      Traceback (most recent call last)
# <ipython-input-16-ae65849d5f58> in <module>
#      12 s3 = s3fs.S3FileSystem(anon=False)
#      13 with s3.open(filenames3, 'wb') as file:
# ---> 14     file.write(byte_encoded_df) #writes byte-encoded file to s3 location
#      15
#      16 #print success message
#
# ~\Anaconda3\lib\site-packages\fsspec\spec.py in __exit__(self, *args)
#    1352
#    1353     def __exit__(self, *args):
# -> 1354         self.close()
#
# ~\Anaconda3\lib\site-packages\fsspec\spec.py in close(self)
#    1320         else:
#    1321             if not self.forced:
# -> 1322                 self.flush(force=True)
#    1323
#    1324             if self.fs is not None:
#
# ~\Anaconda3\lib\site-packages\fsspec\spec.py in flush(self, force)
#    1194             self._initiate_upload()
#    1195
# -> 1196         if self._upload_chunk(final=force) is not False:
#    1197             self.offset += self.buffer.seek(0, 2)
#    1198             self.buffer = io.BytesIO()
#
# ~\Anaconda3\lib\site-packages\s3fs\core.py in _upload_chunk(self, final)
#    1250
#    1251         if self.autocommit and final:
# -> 1252             self.commit()
#    1253         return not final
#    1254
#
# ~\Anaconda3\lib\site-packages\s3fs\core.py in commit(self)
#    1267                 write_result = self._call_s3(
#    1268                     self.fs.s3.put_object,
# -> 1269                     Key=self.key, Bucket=self.bucket, Body=data, **self.kwargs
#    1270                 )
#    1271                 if self.fs.version_aware:
#
# ~\Anaconda3\lib\site-packages\s3fs\core.py in _call_s3(self, method, *kwarglist, **kwargs)
#    1129     def _call_s3(self, method, *kwarglist, **kwargs):
#    1130         return self.fs._call_s3(method, self.s3_additional_kwargs, *kwarglist,
# -> 1131                                 **kwargs)
#    1132
#    1133     def _initiate_upload(self):
#
# ~\Anaconda3\lib\site-packages\s3fs\core.py in _call_s3(self, method, *akwarglist, **kwargs)
#     198         additional_kwargs = self._get_s3_method_kwargs(method, *akwarglist,
#     199                                                        **kwargs)
# --> 200         return method(**additional_kwargs)
#     201
#     202     def _get_s3_method_kwargs(self, method, *akwarglist, **kwargs):
#
# ~\Anaconda3\lib\site-packages\botocore\client.py in _api_call(self, *args, **kwargs)
#     314                     "%s() only accepts keyword arguments." % py_operation_name)
#     315             # The "self" in this scope is referring to the BaseClient.
# --> 316             return self._make_api_call(operation_name, kwargs)
#     317
#     318         _api_call.__name__ = str(py_operation_name)
#
# ~\Anaconda3\lib\site-packages\botocore\client.py in _make_api_call(self, operation_name, api_params)
#     597         }
#     598         request_dict = self._convert_to_request_dict(
# --> 599             api_params, operation_model, context=request_context)
#     600
#     601         service_id = self._service_model.service_id.hyphenize()
#
# ~\Anaconda3\lib\site-packages\botocore\client.py in _convert_to_request_dict(self, api_params, operation_model, context)
#     643                                  context=None):
#     644         api_params = self._emit_api_params(
# --> 645             api_params, operation_model, context)
#     646         request_dict = self._serializer.serialize_to_request(
#     647             api_params, operation_model)
#
# ~\Anaconda3\lib\site-packages\botocore\client.py in _emit_api_params(self, api_params, operation_model, context)
#     675                 service_id=service_id,
#     676                 operation_name=operation_name),
# --> 677             params=api_params, model=operation_model, context=context)
#     678         return api_params
#     679
#
# ~\Anaconda3\lib\site-packages\botocore\hooks.py in emit(self, event_name, **kwargs)
#     354     def emit(self, event_name, **kwargs):
#     355         aliased_event_name = self._alias_event_name(event_name)
# --> 356         return self._emitter.emit(aliased_event_name, **kwargs)
#     357
#     358     def emit_until_response(self, event_name, **kwargs):
#
# ~\Anaconda3\lib\site-packages\botocore\hooks.py in emit(self, event_name, **kwargs)
#     226                  handlers.
#     227         """
# --> 228         return self._emit(event_name, kwargs)
#     229
#     230     def emit_until_response(self, event_name, **kwargs):
#
# ~\Anaconda3\lib\site-packages\botocore\hooks.py in _emit(self, event_name, kwargs, stop_on_response)
#     209         for handler in handlers_to_call:
#     210             logger.debug('Event %s: calling handler %s', event_name, handler)
# --> 211             response = handler(**kwargs)
#     212             responses.append((handler, response))
#     213             if stop_on_response and response is not None:
#
# ~\Anaconda3\lib\site-packages\botocore\handlers.py in validate_bucket_name(params, **kwargs)
#     226             'the regex "%s" or be an ARN matching the regex "%s"' % (
#     227                 bucket, VALID_BUCKET.pattern, VALID_S3_ARN.pattern))
# --> 228         raise ParamValidationError(report=error_msg)
#     229
#     230
#
# ParamValidationError: Parameter validation failed:
# Invalid bucket name "C:": Bucket name must match the regex "^[a-zA-Z0-9.\-_]{1,255}$" or be an ARN matching the regex "^arn:(aws).*:s3:[a-z\-0-9]+:[0-9]{12}:accesspoint[/:][a-zA-Z0-9\-]{1,63}$"

# %%
byte_encoded_df
# Out:
# b',contributors,coordinates,created_at,entities,extended_entities,favorite_count,favorited,geo,id,id_str,in_reply_to_screen_name,in_reply_to_status_id,in_reply_to_status_id_str,in_reply_to_user_id,in_reply_to_user_id_str,is_quote_status,lang,metadata,place,possibly_sensitive,quoted_status_id,quoted_status_id_str,retweet_count,retweeted,retweeted_status,source,text,truncated,user\r\n0,,,Fri May 01 00:59:54 +0000 2020,"{\'hashtags\': [], \'symbols\': [], \'user_mentions\': [{\'screen_name\': \'doolsetbangtan\', \'name\': \'doolset\xf0\x9f\x8d\x8a\', \'id\': 954887105347452929, \'id_str\': \'954887105347452929\', \'indices\': [3, 18]}, {\'screen_name\': \'BTS_twt\', \'name\': \'\xeb\xb0\xa9\xed\x83\x84\xec\x86\x8c\xeb\x85\x84\xeb\x8b\xa8\', \'id\': 335141638, \'id_str\': \'335141638\', \'indices\': [25, 33]}], \'urls\': []}",,0,False,,1256025519965057024,1256025519965057024,,,,,,True,en,"{\'iso_language_code\': \'en\', \'result_type\': \'recent\'}",,,1.2558521076739072e+18,1255852107673907202,3834,False,"{\'created_at\': \'Thu Apr 30 18:48:41 +0000 2020\', \'id\': 1255932098986328065, \'id_str\': \'1255932098986328065\', \'text\': \'BGM: @BTS_twt -  With Seoul\\n\\nYesterday, Korea reported zero new local COVID-19 cases for the first time in months.\xe2\x80\xa6 https://t.co/0l89k9wkDS\', \'truncated\': True, \'entities\': {\'hashtags\': [], \'symbols\': [], \'user_mentions\': [{\'screen_name\': \'BTS_twt\', \'name\': \'\xeb\xb0\xa9\xed\x83\x84\xec\x86\x8c\xeb\x85\x84\xeb\x8b\xa8\', \'id\': 335141638, \'id_str\': \'335141638\', \'indices\': [5, 13]}], \'urls\': [{\'url\': \'https://t.co/0l89k9wkDS\', \'expanded_url\': \'https://twitter.com/i/web/status/1255932098986328065\', \'display_url\': \'twitter.com/i/web/status/1\xe2\x80\xa6\', \'indices\': [116, 139]}]}, \'metadata\': {\'iso_language_code\': \'en\', \'result_type\': \'recent\'}, \'source\': \'<a href=""https://mobile.twitter.com"" rel=""nofollow"">Twitter Web App</a>\', \'in_reply_to_status_id\': None, \'in_reply_to_status_id_str\': None, \'in_reply_to_user_id\': None, \'in_reply_to_user_id_str\': None, \'in_reply_to_screen_name\': None, \'user\': {\'id\': 954887105347452929, \'id_str\': \'954887105347452929\', \'name\': \'doolset\xf0\x9f\x8d\x8a\', \'screen_name\': \'doolsetbangtan\', \'location\': \'\xf0\x9f\x87\xb0\xf0\x9f\x87\xb7 in \xf0\x9f\x87\xba\xf0\x9f\x87\xb8\', \'description\': \'u/diminie. check out my blog for lyric translations! @TeamWhitePaper\xf0\x9f\x8e\x83\', \'url\': \'https://t.co/rFPqjxJgIb\', \'entities\': {\'url\': {\'urls\': [{\'url\': \'https://t.co/rFPqjxJgIb\', \'expanded_url\': \'http://doolsetbangtan.wordpress.com\', \'display_url\': \'doolsetbangtan.wordpress.com\', \'indices\': [0, 23]}]}, \'description\': {\'urls\': []}}, \'protected\': False, \'followers_count\': 238728, \'friends_count\': 65, \'listed_count\': 2964, \'created_at\': \'Sun Jan 21 01:23:21 +0000 2018\', \'favourites_count\': 6894, \'utc_offset\': None, \'time_zone\': None, \'geo_enabled\': False, \'verified\': False, \'statuses_count\': 11275, \'lang\': None, \'contributors_enabled\': False, \'is_translator\': False, \'is_translation_enabled\': False, \'profile_background_color\': \'000000\', \'profile_background_image_url\': \'http://abs.twimg.com/images/themes/theme1/bg.png\', \'profile_background_image_url_https\': \'https://abs.twimg.com/images/themes/theme1/bg.png\', \'profile_background_tile\': False, \'profile_image_url\': \'http://pbs.twimg.com/profile_images/1245402549366251523/xaHm6X2p_normal.jpg\', \'profile_image_url_https\': \'https://pbs.twimg.com/profile_images/1245402549366251523/xaHm6X2p_normal.jpg\', \'profile_banner_url\': \'https://pbs.twimg.com/profile_banners/954887105347452929/1585762067\', \'profile_link_color\': \'3FA92F\', \'profile_sidebar_border_color\': \'000000\', \'profile_sidebar_fill_color\': \'000000\', \'profile_text_color\': \'000000\', \'profile_use_background_image\': False, \'has_extended_profile\': False, \'default_profile\': False, \'d ...
